# %% [markdown]
# **Ejemplo**

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

def linear_regression(x, y):
    
    n = len(x)
    sum_x = sum(x)
    sum_y = sum(y)
    sum_xy = sum([x[i] * y[i] for i in range(n)])
    sum_x_squared = sum([x[i] * x[i] for i in range(n)])

    m = (n * sum_xy - sum_x * sum_y) / (n * sum_x_squared - sum_x * sum_x)
    b = (sum_y - m * sum_x) / n
    
    print("La pendiente de la línea recta es:", m)
    print("La intersección de la línea recta es:", b)
    
    
    def exponential_func(x, a, b):
        return a * pow(2.71828, b * x)

    popt, pcov = curve_fit(exponential_func, x, y)
    a, b = popt
    print(f'Regresión exponencial: y = {a:.2f}e^({b:.2f}x)')

    
    plt.scatter(x, y)
    plt.plot(x, exponential_func(np.array(x), a, b), 'g-', label='Regresión exponencial')
    plt.legend()
    plt.show()

x = [1,2,3,4,5]
y = [5,6.6,8.5,10.8,14.2]


linear_regression(x, y)
# Out:
# La pendiente de la línea recta es: 2.26
# La intersección de la línea recta es: 2.2400000000000007
# Regresión exponencial: y = 3.90e^(0.26x)

# %% [markdown]
# **Punto del Taller**

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

def linear_regression(x, y):
    
    n = len(x)
    sum_x = sum(x)
    sum_y = sum(y)
    sum_xy = sum([x[i] * y[i] for i in range(n)])
    sum_x_squared = sum([x[i] * x[i] for i in range(n)])

    m = (n * sum_xy - sum_x * sum_y) / (n * sum_x_squared - sum_x * sum_x)
    b = (sum_y - m * sum_x) / n
    
    print("La pendiente de la línea recta es:", m)
    print("La intersección de la línea recta es:", b)
    
    
    def exponential_func(x, a, b):
        return a * pow(2.71828, b * x)

    popt, pcov = curve_fit(exponential_func, x, y)
    a, b = popt
    print(f'Regresión exponencial: y = {a:.2f}e^({b:.2f}x)')

    
    plt.scatter(x, y)
    plt.plot(x, exponential_func(np.array(x), a, b), 'g-', label='Regresión exponencial')
    plt.legend()
    plt.show()


x = [2, 4, 6, 8, 10, 12]
y = [2.2, 3, 4.5, 6, 8.5, 12]


linear_regression(x, y)
# Out:
# La pendiente de la línea recta es: 0.9571428571428566
# La intersección de la línea recta es: -0.6666666666666631
# Regresión exponencial: y = 1.56e^(0.17x)
